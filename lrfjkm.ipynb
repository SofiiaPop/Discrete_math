# %%
from PIL import Image
from IPython.display import display

# %%
image = Image.open('/Users/sofiiapopeniuk/documents/Screenshot1.png')
display(image)
# Out:
# <PIL.PngImagePlugin.PngImageFile image mode=RGBA size=1506x464>

# %% [markdown]
# ![image.png](attachment:image.png)
